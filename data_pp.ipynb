# %%
from scipy.io import loadmat
import numpy as np 
from matplotlib import pyplot as plt

# %%
d = loadmat('10.mat')
images = np.array(d['images'])
images = images.transpose()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\ramzi\anaconda3\lib\site-packages\scipy\io\matlab\mio.py:39, in _open_file(file_like, appendmat, mode)
#      38 try:
# ---> 39     return open(file_like, mode), True
#      40 except IOError as e:
#      41     # Probably "not found"
#
# FileNotFoundError: [Errno 2] No such file or directory: '10.mat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# e:\term1400-2\cognitive science\project\data_pp.ipynb Cell 2 in <module>
# ----> <a href='vscode-notebook-cell:/e%3A/term1400-2/cognitive%20science/project/data_pp.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> d = loadmat('10.mat')
# ...

# %%
plt.imshow(img[95],cmap = 'Greys')
